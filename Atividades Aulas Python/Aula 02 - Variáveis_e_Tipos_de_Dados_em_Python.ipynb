# %% [markdown]
# 9. Exercícios Propostos

# %% [markdown]
# Crie um programa que solicite o nome e a idade do usuário e exiba uma mensagem personalizada.
# Leia dois números informados pelo usuário e exiba a soma.
# Calcule a média de três notas digitadas pelo usuário.
# Crie uma variável booleana que indique se o aluno foi aprovado (nota maior ou igual a 6)

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
print("Bom dia!!,", nome)
# Out:
# Digite seu nome: laryelle
# Digite sua idade: 18
# Bom dia!!, laryelle

# %%
a = 5
b = 5

print(a + b)
# Out:
# 10

# %%
a = 10
b = 10
c = 10

print(a + b + c / 3 )
# Out:
# 23.333333333333332

# %% [markdown]
# Forma onde ele trás a dúvida se o aluno foi aprovado ou não.

# %%
nota = float(input("Digite a nota do aluno: "))

aprovado = nota >= 6

print("Aluno aprovado?", aprovado)
# Out:
# Digite a nota do aluno: 5
# Aluno aprovado? False

# %% [markdown]
# Trás a conclusão final.

# %%
nota = float(input("Digite a nota do aluno: "))

if nota >= 6:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a nota do aluno: 4
# Reprovado

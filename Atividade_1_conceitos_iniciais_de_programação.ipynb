# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
print("Seja bem-vindo,", nome)
# Out:
# Digite seu nome: laryelle
# Digite sua idade: 18
# Seja bem-vindo, laryelle

# %%
a = 5
b = 5

print(a + b)
# Out:
# 10

# %%
a = 5
b = 5
c = 5

print(a + b + c / 3)
# Out:
# 11.666666666666666

# %% [markdown]
# agora juntando tudo

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
print("Seja bem-vindo,", nome)
print("Soma de 2 variaveis,")
a = 5
b = 5

print(a + b)

print("média entre 3 variáveis,")
a = 5
b = 5
c = 5

print(a + b + c / 3)
# Out:
# Digite seu nome: laryelle
# Digite sua idade: 18
# Seja bem-vindo, laryelle
# Soma de 2 variaveis,
# 10
# média entre 3 variáveis,
# 11.666666666666666
